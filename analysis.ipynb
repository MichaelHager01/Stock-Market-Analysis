# %% [markdown]
# # ***Stock Market Analysis***
#
# ## Objective:
#
# - Develop a stock market prediction app using Tkinter in Python.
# - Utilize TensorFlow and Scikit-learn to implement neural networks and linear regression models.
# - Aim to achieve accurate stock market predictions through comprehensive data analysis and model optimization techniques.

# %% [markdown]
# ## Data Visualization:
#
# Microsoft Corporation-Dataset
#
# https://finance.yahoo.com/quote/MSFT

# %%
from google.colab import drive

# Connect to Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Read the data from Excel file
df = pd.read_csv('MSFT (1).csv')

# Convert 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Sort the DataFrame by the Date column
df.sort_values(by='Date', inplace=True)

# Keep the Date and Close columns
df = df[['Date', 'Close']]

# Set index to Date column
df.index = df.pop('Date')

# Visualize data format
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2024-03-13  415.100006
# 2024-03-14  425.220001
# 2024-03-15  416.420013
# 2024-03-18  417.320007
# 2024-03-19  421.410004
#
# [9581 rows x 1 columns]

# %% [markdown]
# ## Data Splitting, Pre-processing and Model Training:

# %%
import numpy as np
import datetime

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = pd.to_datetime(first_date_str)
  last_date = pd.to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day is 3 days past first day since we are predicting days based on past 3 days
windowed_df = df_to_windowed_df(df,
                                '2021-03-25',
                                '2022-03-30',
                                n=3)

windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 252  2022-03-24  299.160004  304.059998  299.489990  304.100006
# 253  2022-03-25  304.059998  299.489990  304.100006  303.679993
# 254  2022-03-28  299.489990  304.100006  303.679993  310.700012
# 255  2022-03-29  304.100006  303.679993  310.700012  315.410004
# 256  2022-03-30  303.679993  310.700012  315.410004  313.859985
#
# [257 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

# Convert to matrix for Tensorflow
dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((257,), (257, 3, 1), (257,))

# %%
from matplotlib import pyplot as plt

q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]
dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 3s 92ms/step - loss: 85139.7188 - mean_absolute_error: 290.0667 - val_loss: 90475.9922 - val_mean_absolute_error: 300.7059
# Epoch 2/100
# 7/7 [==============================] - 0s 8ms/step - loss: 84908.2422 - mean_absolute_error: 289.6656 - val_loss: 90279.1797 - val_mean_absolute_error: 300.3784
# Epoch 3/100
# 7/7 [==============================] - 0s 8ms/step - loss: 84706.8672 - mean_absolute_error: 289.3187 - val_loss: 90037.2578 - val_mean_absolute_error: 299.9754
# Epoch 4/100
# 7/7 [==============================] - 0s 8ms/step - loss: 84433.1406 - mean_absolute_error: 288.8446 - val_loss: 89716.7891 - val_mean_absolute_error: 299.4409
# Epoch 5/100
# 7/7 [==============================] - 0s 8ms/step - loss: 84145.7578 - mean_absolute_error: 288.3474 - val_loss: 89431.5859 - val_mean_absolute_error: 298.9642
# Epoch 6/100
# 7/7 [==============================] - 0s 8ms/step - loss: 83855.8438 - mean_absolute_error: 287.8440 - val_loss: 89097.5312 - val_mean_absolute_error: 298.4050
# Epoch 7/100
# 7/7 [==============================] - 0s 8ms/step - loss: 83494.8984 - mean_absolute_error: 287.2137 - val_loss: 88626.1797 - val_mean_absolute_error: 297.6141
# Epoch 8/100
# 7/7 [==============================] - 0s 8ms/step - loss: 82878.9688 - mean_absolute_error: 286.1426 - val_loss: 87642.6641 - val_mean_absolute_error: 295.9571
# Epoch 9/100
# 7/7 [==============================] - 0s 8ms/step - loss: 81670.7109 - mean_absolute_error: 284.0317 - val_loss: 86103.5156 - val_mean_absolute_error: 293.3454
# Epoch 10/100
# 7/7 [==============================] - 0s 8ms/step - loss: 80231.5547 - mean_absolute_error: 281.4864 - val_loss: 84662.2500 - val_mean_absolute_error: 290.8784
# Epoch 11/100
# 7/7 [==============================] - 0s 8ms/step - loss: 78747.7031 - mean_absolute_error: 278.8277 - val_loss: 82905.4453 - val_mean_absolute_error: 287.8427
# Epoch 12/100
# 7/7 [==============================] - 0s 8ms/step - loss: 76976.5469 - mean_absolute_error: 275.6390 - val_loss: 80925.4453 - val_mean_absolute_error: 284.3825
# Epoch 13/100
# 7/7 [==============================] - 0s 10ms/step - loss: 74829.2578 - mean_absolute_error: 271.7132 - val_loss: 78130.7344 - val_mean_absolute_error: 279.4254
# Epoch 14/100
# 7/7 [==============================] - 0s 8ms/step - loss: 71625.3984 - mean_absolute_error: 265.7363 - val_loss: 74083.2031 - val_mean_absolute_error: 272.0867
# Epoch 15/100
# 7/7 [==============================] - 0s 9ms/step - loss: 67694.0469 - mean_absolute_error: 258.2239 - val_loss: 69709.7344 - val_mean_absolute_error: 263.9272
# Epoch 16/100
# 7/7 [==============================] - 0s 8ms/step - loss: 63077.2930 - mean_absolute_error: 249.1331 - val_loss: 64614.5469 - val_mean_absolute_error: 254.0916
# Epoch 17/100
# 7/7 [==============================] - 0s 8ms/step - loss: 58108.0391 - mean_absolute_error: 238.9210 - val_loss: 58932.1172 - val_mean_absolute_error: 242.6518
# Epoch 18/100
# 7/7 [==============================] - 0s 8ms/step - loss: 52300.9023 - mean_absolute_error: 226.3938 - val_loss: 52072.2148 - val_mean_absolute_error: 228.0789
# Epoch 19/100
# 7/7 [==============================] - 0s 9ms/step - loss: 45546.6250 - mean_absolute_error: 210.9560 - val_loss: 45113.4414 - val_mean_absolute_error: 212.2768
# Epoch 20/100
# 7/7 [==============================] - 0s 8ms/step - loss: 38997.3242 - mean_absolute_error: 194.9155 - val_loss: 38068.7461 - val_mean_absolute_error: 194.9787
# Epoch 21/100
# 7/7 [==============================] - 0s 8ms/step - loss: 32367.4902 - mean_absolute_error: 176.9437 - val_loss: 31222.3105 - val_mean_absolute_error: 176.5512
# Epoch 22/100
# 7/7 [==============================] - 0s 8ms/step - loss: 26039.3418 - mean_absolute_error: 158.1807 - val_loss: 24743.6562 - val_mean_absolute_error: 157.1358
# Epoch 23/100
# 7/7 [==============================] - 0s 8ms/step - loss: 20178.6016 - mean_absolute_error: 138.3905 - val_loss: 18772.5840 - val_mean_absolute_error: 136.8229
# Epoch 24/100
# 7/7 [==============================] - 0s 8ms/step - loss: 14847.1582 - mean_absolute_error: 117.3941 - val_loss: 13204.9854 - val_mean_absolute_error: 114.6862
# Epoch 25/100
# 7/7 [==============================] - 0s 8ms/step - loss: 10175.7637 - mean_absolute_error: 95.6905 - val_loss: 8903.4473 - val_mean_absolute_error: 94.0822
# Epoch 26/100
# 7/7 [==============================] - 0s 8ms/step - loss: 6689.0376 - mean_absolute_error: 75.4737 - val_loss: 5610.0361 - val_mean_absolute_error: 74.5524
# Epoch 27/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4226.3955 - mean_absolute_error: 56.5697 - val_loss: 3260.8384 - val_mean_absolute_error: 56.6468
# Epoch 28/100
# 7/7 [==============================] - 0s 8ms/step - loss: 2589.0195 - mean_absolute_error: 41.3931 - val_loss: 1750.2495 - val_mean_absolute_error: 41.2089
# Epoch 29/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1646.6450 - mean_absolute_error: 33.2689 - val_loss: 769.0973 - val_mean_absolute_error: 26.7786
# Epoch 30/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1153.6926 - mean_absolute_error: 28.9483 - val_loss: 352.5744 - val_mean_absolute_error: 17.3377
# Epoch 31/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1025.0615 - mean_absolute_error: 27.2047 - val_loss: 184.3426 - val_mean_absolute_error: 11.7800
# Epoch 32/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1002.6099 - mean_absolute_error: 26.8619 - val_loss: 128.5093 - val_mean_absolute_error: 9.7569
# Epoch 33/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1010.5230 - mean_absolute_error: 26.8526 - val_loss: 105.3194 - val_mean_absolute_error: 8.7571
# Epoch 34/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1013.4005 - mean_absolute_error: 26.8759 - val_loss: 117.5541 - val_mean_absolute_error: 9.3066
# Epoch 35/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1009.9776 - mean_absolute_error: 26.8639 - val_loss: 118.6072 - val_mean_absolute_error: 9.3517
# Epoch 36/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1004.7135 - mean_absolute_error: 26.7972 - val_loss: 130.0279 - val_mean_absolute_error: 9.8168
# Epoch 37/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1000.7209 - mean_absolute_error: 26.7824 - val_loss: 153.9259 - val_mean_absolute_error: 10.6972
# Epoch 38/100
# 7/7 [==============================] - 0s 12ms/step - loss: 998.9657 - mean_absolute_error: 26.7631 - val_loss: 163.3767 - val_mean_absolute_error: 11.0491
# Epoch 39/100
# 7/7 [==============================] - 0s 13ms/step - loss: 999.0362 - mean_absolute_error: 26.7579 - val_loss: 175.3121 - val_mean_absolute_error: 11.4727
# Epoch 40/100
# 7/7 [==============================] - 0s 9ms/step - loss: 997.6016 - mean_absolute_error: 26.7409 - val_loss: 177.0898 - val_mean_absolute_error: 11.5341
# Epoch 41/100
# 7/7 [==============================] - 0s 9ms/step - loss: 997.2035 - mean_absolute_error: 26.7340 - val_loss: 175.3140 - val_mean_absolute_error: 11.4728
# Epoch 42/100
# 7/7 [==============================] - 0s 11ms/step - loss: 996.6765 - mean_absolute_error: 26.7276 - val_loss: 172.2287 - val_mean_absolute_error: 11.3653
# Epoch 43/100
# 7/7 [==============================] - 0s 11ms/step - loss: 996.1837 - mean_absolute_error: 26.7210 - val_loss: 170.8164 - val_mean_absolute_error: 11.3157
# Epoch 44/100
# 7/7 [==============================] - 0s 9ms/step - loss: 995.8469 - mean_absolute_error: 26.7217 - val_loss: 166.2894 - val_mean_absolute_error: 11.1545
# Epoch 45/100
# 7/7 [==============================] - 0s 9ms/step - loss: 996.0129 - mean_absolute_error: 26.7225 - val_loss: 159.7713 - val_mean_absolute_error: 10.9169
# Epoch 46/100
# 7/7 [==============================] - 0s 12ms/step - loss: 995.4072 - mean_absolute_error: 26.7145 - val_loss: 160.4172 - val_mean_absolute_error: 10.9408
# Epoch 47/100
# 7/7 [==============================] - 0s 15ms/step - loss: 996.3470 - mean_absolute_error: 26.7288 - val_loss: 172.5897 - val_mean_absolute_error: 11.3780
# Epoch 48/100
# 7/7 [==============================] - 0s 17ms/step - loss: 994.3120 - mean_absolute_error: 26.6945 - val_loss: 172.1337 - val_mean_absolute_error: 11.3618
# Epoch 49/100
# 7/7 [==============================] - 0s 16ms/step - loss: 976.8222 - mean_absolute_error: 26.4962 - val_loss: 247.0718 - val_mean_absolute_error: 14.0209
# Epoch 50/100
# 7/7 [==============================] - 0s 16ms/step - loss: 957.8854 - mean_absolute_error: 26.2103 - val_loss: 216.9901 - val_mean_absolute_error: 12.9272
# Epoch 51/100
# 7/7 [==============================] - 0s 14ms/step - loss: 923.2805 - mean_absolute_error: 25.7476 - val_loss: 557.6979 - val_mean_absolute_error: 22.5946
# Epoch 52/100
# 7/7 [==============================] - 0s 12ms/step - loss: 863.4583 - mean_absolute_error: 24.9108 - val_loss: 163.6900 - val_mean_absolute_error: 11.0569
# Epoch 53/100
# 7/7 [==============================] - 0s 9ms/step - loss: 821.9096 - mean_absolute_error: 24.3774 - val_loss: 128.4654 - val_mean_absolute_error: 9.7507
# Epoch 54/100
# 7/7 [==============================] - 0s 14ms/step - loss: 768.1097 - mean_absolute_error: 23.2603 - val_loss: 161.3843 - val_mean_absolute_error: 10.9461
# Epoch 55/100
# 7/7 [==============================] - 0s 12ms/step - loss: 701.4228 - mean_absolute_error: 22.3386 - val_loss: 123.9313 - val_mean_absolute_error: 9.5479
# Epoch 56/100
# 7/7 [==============================] - 0s 11ms/step - loss: 657.5453 - mean_absolute_error: 21.5370 - val_loss: 144.7361 - val_mean_absolute_error: 10.3277
# Epoch 57/100
# 7/7 [==============================] - 0s 9ms/step - loss: 607.0269 - mean_absolute_error: 20.7053 - val_loss: 124.8028 - val_mean_absolute_error: 9.5512
# Epoch 58/100
# 7/7 [==============================] - 0s 9ms/step - loss: 562.8615 - mean_absolute_error: 19.8419 - val_loss: 67.9620 - val_mean_absolute_error: 6.9093
# Epoch 59/100
# 7/7 [==============================] - 0s 9ms/step - loss: 520.9801 - mean_absolute_error: 19.0528 - val_loss: 96.5160 - val_mean_absolute_error: 8.3443
# Epoch 60/100
# 7/7 [==============================] - 0s 9ms/step - loss: 466.8106 - mean_absolute_error: 17.9399 - val_loss: 136.7661 - val_mean_absolute_error: 10.1135
# Epoch 61/100
# 7/7 [==============================] - 0s 9ms/step - loss: 387.3742 - mean_absolute_error: 16.3377 - val_loss: 120.4179 - val_mean_absolute_error: 9.3643
# Epoch 62/100
# 7/7 [==============================] - 0s 13ms/step - loss: 354.3185 - mean_absolute_error: 15.4590 - val_loss: 124.1492 - val_mean_absolute_error: 9.5583
# Epoch 63/100
# 7/7 [==============================] - 0s 10ms/step - loss: 309.7664 - mean_absolute_error: 14.4733 - val_loss: 161.5920 - val_mean_absolute_error: 11.4022
# Epoch 64/100
# 7/7 [==============================] - 0s 9ms/step - loss: 274.9807 - mean_absolute_error: 13.4329 - val_loss: 147.1912 - val_mean_absolute_error: 10.7793
# Epoch 65/100
# 7/7 [==============================] - 0s 10ms/step - loss: 239.4394 - mean_absolute_error: 12.5837 - val_loss: 59.2692 - val_mean_absolute_error: 6.3072
# Epoch 66/100
# 7/7 [==============================] - 0s 10ms/step - loss: 194.6319 - mean_absolute_error: 11.0414 - val_loss: 31.8451 - val_mean_absolute_error: 4.7664
# Epoch 67/100
# 7/7 [==============================] - 0s 9ms/step - loss: 161.5111 - mean_absolute_error: 9.8589 - val_loss: 30.6217 - val_mean_absolute_error: 4.7188
# Epoch 68/100
# 7/7 [==============================] - 0s 15ms/step - loss: 135.1280 - mean_absolute_error: 9.0562 - val_loss: 30.1075 - val_mean_absolute_error: 4.6958
# Epoch 69/100
# 7/7 [==============================] - 0s 10ms/step - loss: 115.7606 - mean_absolute_error: 8.2417 - val_loss: 33.3146 - val_mean_absolute_error: 4.8834
# Epoch 70/100
# 7/7 [==============================] - 0s 9ms/step - loss: 99.4645 - mean_absolute_error: 7.6590 - val_loss: 30.8140 - val_mean_absolute_error: 4.7543
# Epoch 71/100
# 7/7 [==============================] - 0s 12ms/step - loss: 88.3184 - mean_absolute_error: 7.1153 - val_loss: 29.6024 - val_mean_absolute_error: 4.6341
# Epoch 72/100
# 7/7 [==============================] - 0s 9ms/step - loss: 71.9611 - mean_absolute_error: 6.2264 - val_loss: 30.7419 - val_mean_absolute_error: 4.7339
# Epoch 73/100
# 7/7 [==============================] - 0s 9ms/step - loss: 61.2295 - mean_absolute_error: 5.7603 - val_loss: 41.5636 - val_mean_absolute_error: 5.3496
# Epoch 74/100
# 7/7 [==============================] - 0s 8ms/step - loss: 55.0817 - mean_absolute_error: 5.6334 - val_loss: 122.0729 - val_mean_absolute_error: 9.6366
# Epoch 75/100
# 7/7 [==============================] - 0s 9ms/step - loss: 71.9418 - mean_absolute_error: 7.1812 - val_loss: 29.9802 - val_mean_absolute_error: 4.6246
# Epoch 76/100
# 7/7 [==============================] - 0s 9ms/step - loss: 56.2584 - mean_absolute_error: 6.1325 - val_loss: 33.0058 - val_mean_absolute_error: 4.7711
# Epoch 77/100
# 7/7 [==============================] - 0s 13ms/step - loss: 52.3762 - mean_absolute_error: 5.9195 - val_loss: 35.0638 - val_mean_absolute_error: 4.9798
# Epoch 78/100
# 7/7 [==============================] - 0s 10ms/step - loss: 44.7600 - mean_absolute_error: 5.3387 - val_loss: 61.2053 - val_mean_absolute_error: 6.4139
# Epoch 79/100
# 7/7 [==============================] - 0s 12ms/step - loss: 43.2967 - mean_absolute_error: 5.3092 - val_loss: 86.4921 - val_mean_absolute_error: 7.8254
# Epoch 80/100
# 7/7 [==============================] - 0s 9ms/step - loss: 35.2119 - mean_absolute_error: 4.6973 - val_loss: 52.8436 - val_mean_absolute_error: 6.0574
# Epoch 81/100
# 7/7 [==============================] - 0s 13ms/step - loss: 31.7417 - mean_absolute_error: 4.4371 - val_loss: 32.5002 - val_mean_absolute_error: 4.7907
# Epoch 82/100
# 7/7 [==============================] - 0s 13ms/step - loss: 30.6744 - mean_absolute_error: 4.2577 - val_loss: 33.5750 - val_mean_absolute_error: 4.8569
# Epoch 83/100
# 7/7 [==============================] - 0s 8ms/step - loss: 31.3190 - mean_absolute_error: 4.4084 - val_loss: 35.3358 - val_mean_absolute_error: 4.9797
# Epoch 84/100
# 7/7 [==============================] - 0s 8ms/step - loss: 30.6627 - mean_absolute_error: 4.3239 - val_loss: 51.3589 - val_mean_absolute_error: 6.0149
# Epoch 85/100
# 7/7 [==============================] - 0s 10ms/step - loss: 27.0750 - mean_absolute_error: 4.0719 - val_loss: 86.3501 - val_mean_absolute_error: 7.7941
# Epoch 86/100
# 7/7 [==============================] - 0s 8ms/step - loss: 26.9246 - mean_absolute_error: 4.1172 - val_loss: 31.3167 - val_mean_absolute_error: 4.6143
# Epoch 87/100
# 7/7 [==============================] - 0s 8ms/step - loss: 32.0514 - mean_absolute_error: 4.5674 - val_loss: 31.0435 - val_mean_absolute_error: 4.6161
# Epoch 88/100
# 7/7 [==============================] - 0s 8ms/step - loss: 25.8872 - mean_absolute_error: 4.0642 - val_loss: 33.1526 - val_mean_absolute_error: 4.8129
# Epoch 89/100
# 7/7 [==============================] - 0s 11ms/step - loss: 27.7012 - mean_absolute_error: 4.1143 - val_loss: 47.5791 - val_mean_absolute_error: 5.8308
# Epoch 90/100
# 7/7 [==============================] - 0s 8ms/step - loss: 29.2327 - mean_absolute_error: 4.2000 - val_loss: 74.4898 - val_mean_absolute_error: 7.1293
# Epoch 91/100
# 7/7 [==============================] - 0s 8ms/step - loss: 29.7943 - mean_absolute_error: 4.3778 - val_loss: 75.9328 - val_mean_absolute_error: 7.1825
# Epoch 92/100
# 7/7 [==============================] - 0s 8ms/step - loss: 29.4281 - mean_absolute_error: 4.2262 - val_loss: 40.8942 - val_mean_absolute_error: 5.4043
# Epoch 93/100
# 7/7 [==============================] - 0s 8ms/step - loss: 27.5276 - mean_absolute_error: 4.2540 - val_loss: 32.6009 - val_mean_absolute_error: 4.6692
# Epoch 94/100
# 7/7 [==============================] - 0s 8ms/step - loss: 28.1817 - mean_absolute_error: 4.2575 - val_loss: 31.9585 - val_mean_absolute_error: 4.6153
# Epoch 95/100
# 7/7 [==============================] - 0s 9ms/step - loss: 29.1117 - mean_absolute_error: 4.4110 - val_loss: 34.5525 - val_mean_absolute_error: 4.8229
# Epoch 96/100
# 7/7 [==============================] - 0s 8ms/step - loss: 27.3570 - mean_absolute_error: 4.1473 - val_loss: 42.2239 - val_mean_absolute_error: 5.5015
# Epoch 97/100
# 7/7 [==============================] - 0s 10ms/step - loss: 19.8479 - mean_absolute_error: 3.5042 - val_loss: 37.3561 - val_mean_absolute_error: 5.1247
# Epoch 98/100
# 7/7 [==============================] - 0s 8ms/step - loss: 23.3208 - mean_absolute_error: 3.8186 - val_loss: 31.8554 - val_mean_absolute_error: 4.6386
# Epoch 99/100
# 7/7 [==============================] - 0s 12ms/step - loss: 24.4486 - mean_absolute_error: 3.9293 - val_loss: 33.0221 - val_mean_absolute_error: 4.7855
# Epoch 100/100
# 7/7 [==============================] - 0s 13ms/step - loss: 19.8426 - mean_absolute_error: 3.5228 - val_loss: 41.2800 - val_mean_absolute_error: 5.4353

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 1s 2ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 28ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy
from datetime import timedelta

# Specify the number of days to predict
num_days_to_predict = 40

# Initialize last window with the last window from the test set
last_window = deepcopy(X_test[-1])
recursive_predictions = []
recursive_dates = np.array([dates[-1]])

# Predict for the next num_days_to_predict days
for i in range(num_days_to_predict):
  # Predict the next day's 'Close' price
  next_prediction = model.predict(np.array([last_window])).flatten()

  # Append the prediction to the list of predictions
  recursive_predictions.append(next_prediction)

  # Shift the last window to include the new prediction for the next iteration
  last_window = np.concatenate([last_window[1:], next_prediction.reshape(1, -1)], axis=0)

  # Update the target date to the next day
  target_date = recursive_dates[-1] + timedelta(days=1)

  # Append the target date to the list of dates
  recursive_dates = np.append(recursive_dates, target_date)

recursive_dates = recursive_dates[1:]
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
